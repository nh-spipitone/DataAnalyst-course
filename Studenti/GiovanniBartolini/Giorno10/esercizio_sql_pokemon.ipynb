# %% [markdown]
# ### Esercizio Pokemon
#
# 1. Carica il dataset pokemon sul database postgress
# 2. fai una view con tutti i pokemon di tipo fuoco e con più di 70hp
# 3. mostra il pokemon con più attacco di tutti
# 4. mostra le statistiche di moltres
# 5. crea una funzione che permetta di cercare i pokemon per nome
#
# ### Extra
#
# Scopriamo quale pokemon dalle statistiche è il più forte se presente

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Creazione connessione al database PostgreSQL
engine = create_engine("postgresql+psycopg2://postgres:mypassword@localhost:5432/esercizio")

# %%
pokemon_df = pd.read_csv("/home/giovanni/Programs/Python3/DataAnalyst-course/Esercizi/Giorno 10/pokemon_data.csv")
pokemon_df
# Out:
#          id                      name  base_experience  height  weight  \
# 0         1                 bulbasaur               64       7      69
# 1         2                   ivysaur              142      10     130
# 2         3                  venusaur              236      20    1000
# 3         4                charmander               62       6      85
# 4         5                charmeleon              142      11     190
# ...     ...                       ...              ...     ...     ...
# 1297  10273   ogerpon-wellspring-mask              275      12     398
# 1298  10274  ogerpon-hearthflame-mask              275      12     398
# 1299  10275  ogerpon-cornerstone-mask              275      12     398
# 1300  10276        terapagos-terastal               90       3     160
# 1301  10277         terapagos-stellar               90      17     770
#
#               types              abilities  \
# 0     grass, poison  overgrow, chlorophyll
# ...

# %%
# carica il DataFrame nel database
pokemon_df.to_sql('pokemon', engine, if_exists='replace', index=False)
# Out:
# 302

# %%
# salva il dataframe in un file sqlite
pokemon_df.to_sql('pokemon', 'sqlite:///pokemon.db', if_exists='replace', index=False)
# Out:
# 1302

# %%
# filtra i pokemon di tipo "fire" (solo mono tipo)
fire_pokemon_query = text("SELECT * FROM pokemon WHERE types = 'fire'")
fire_pokemon = pd.read_sql(fire_pokemon_query, engine)
fire_pokemon
# Out:
#        id                 name  base_experience  height  weight types  \
# 0       4           charmander               62       6      85  fire
# 1       5           charmeleon              142      11     190  fire
# 2      37               vulpix               60       6      99  fire
# 3      38            ninetales              177      11     199  fire
# 4      58            growlithe               70       7     190  fire
# 5      59             arcanine              194      19    1550  fire
# 6      77               ponyta               82      10     300  fire
# 7      78             rapidash              175      17     950  fire
# 8     126               magmar              173      13     445  fire
# 9     136              flareon              184       9     250  fire
# 10    155            cyndaquil               62       5      79  fire
# 11    156              quilava              142       9     190  fire
# ...

# %%
# filtra i pokemon di tipo "fire" (anche multi tipo)
fire_multi_pokemon_query = text("SELECT * FROM pokemon WHERE types LIKE '%fire%'")
fire_multi_pokemon = pd.read_sql(fire_multi_pokemon_query, engine)
fire_multi_pokemon
# Out:
#         id                       name  base_experience  height  weight  \
# 0        4                 charmander               62       6      85
# 1        5                 charmeleon              142      11     190
# 2        6                  charizard              240      17     905
# 3       37                     vulpix               60       6      99
# 4       38                  ninetales              177      11     199
# ..     ...                        ...              ...     ...     ...
# 98   10229            growlithe-hisui               70       8     227
# 99   10230             arcanine-hisui              194      20    1680
# 100  10233           typhlosion-hisui              240      16     698
# 101  10251  tauros-paldea-blaze-breed              172      14     850
# 102  10274   ogerpon-hearthflame-mask              275      12     398
#
#               types                          abilities  \
# 0              fire                 blaze, solar-power
# ...

# %%
# filtra i pokemon con hp maggiore di 170
hp_query = text("""
	SELECT * FROM pokemon
	WHERE CAST(
		regexp_replace(stats, '^.*hp=([0-9]+).*$','\\1') AS INTEGER
	) > 170
""")
hp_pokemon = pd.read_sql(hp_query, engine)
hp_pokemon[['name', 'types', 'stats']]
# Out:
#                   name           types  \
# 0              chansey          normal
# 1            wobbuffet         psychic
# 2              blissey          normal
# 3             guzzlord    dark, dragon
# 4            regidrago          dragon
# 5     zygarde-complete  dragon, ground
# 6  eternatus-eternamax  poison, dragon
#
#                                                stats
# 0  hp=250, attack=5, defense=5, special-attack=35...
# 1  hp=190, attack=33, defense=58, special-attack=...
# 2  hp=255, attack=10, defense=10, special-attack=...
# 3  hp=223, attack=101, defense=53, special-attack...
# 4  hp=200, attack=100, defense=50, special-attack...
# 5  hp=216, attack=100, defense=121, special-attac...
# 6  hp=255, attack=115, defense=250, special-attac...

# %%
# printa la colonna stats per intero per il pokemon chansey
chansey_stats_query = text("""
    SELECT stats FROM pokemon
    WHERE name = 'chansey'
""")
chansey_stats = pd.read_sql(chansey_stats_query, engine)
chansey_stats['stats'].values[0]  # Stampa la colonna stats per Chansey
# Out:
# 'hp=250, attack=5, defense=5, special-attack=35, special-defense=105, speed=50'

# %%
# accedi al database splittando le stats in colonne separate
stats_query = text("""
    SELECT
        id, name, types, abilities,
        CAST(regexp_replace(stats, '^.*hp=([0-9]+).*$','\\1') AS INTEGER) AS hp,
        CAST(regexp_replace(stats, '^.* attack=([0-9]+).*$','\\1') AS INTEGER) AS attack,
        CAST(regexp_replace(stats, '^.* defense=([0-9]+).*$','\\1') AS INTEGER) AS defense,
        CAST(regexp_replace(stats, '^.*special-attack=([0-9]+).*$','\\1') AS INTEGER) AS sp_attack,
        CAST(regexp_replace(stats, '^.*special-defense=([0-9]+).*$','\\1') AS INTEGER) AS sp_defense,
        CAST(regexp_replace(stats, '^.*speed=([0-9]+).*$','\\1') AS INTEGER) AS speed,
        CAST(regexp_replace(stats, '^.*hp=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.* attack=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.* defense=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.*special-attack=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.*special-defense=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.*speed=([0-9]+).*$','\\1') AS INTEGER) AS total_stats
    FROM pokemon
""")
pokemon_stats_df = pd.read_sql(stats_query, engine)
pokemon_stats_df.head(20)
# Out:
#     id        name           types                          abilities  hp  \
# 0    1   bulbasaur   grass, poison              overgrow, chlorophyll  45
# 1    2     ivysaur   grass, poison              overgrow, chlorophyll  60
# 2    3    venusaur   grass, poison              overgrow, chlorophyll  80
# 3    4  charmander            fire                 blaze, solar-power  39
# 4    5  charmeleon            fire                 blaze, solar-power  58
# 5    6   charizard    fire, flying                 blaze, solar-power  78
# 6    7    squirtle           water                 torrent, rain-dish  44
# 7    8   wartortle           water                 torrent, rain-dish  59
# 8    9   blastoise           water                 torrent, rain-dish  79
# 9   10    caterpie             bug              shield-dust, run-away  45
# 10  11     metapod             bug                          shed-skin  50
# 11  12  butterfree     bug, flying         compound-eyes, tinted-lens  60
# ...

# %%
# rimuovi la colonna stats originale
# pokemon_stats_df.drop(columns=['stats'], inplace=True)
# pokemon_stats_df.head(10)

# %%
# carica il DataFrame nel database
pokemon_stats_df.to_sql('pokemon_stats', engine, if_exists='replace', index=False)
# salva il dataframe in un file sqlite
pokemon_stats_df.to_sql('pokemon_stats', 'sqlite:///pokemon.db', if_exists='replace', index=False)
# Out:
# 1302

# %%
# filtra i Pokémon fire con HP superiore a 70
fire_hp_query = text("""
    SELECT * FROM pokemon_stats WHERE types LIKE '%fire%' AND hp > 70
""")
fire_hp_pokemon = pd.read_sql(fire_hp_query, engine)
fire_hp_pokemon
# Out:
#        id                       name           types  \
# 0       6                  charizard    fire, flying
# 1      38                  ninetales            fire
# 2      59                   arcanine            fire
# 3     146                    moltres    fire, flying
# 4     157                 typhlosion            fire
# 5     229                   houndoom      dark, fire
# 6     244                      entei            fire
# 7     250                      ho-oh    fire, flying
# 8     257                   blaziken  fire, fighting
# 9     392                  infernape  fire, fighting
# 10    467                  magmortar            fire
# 11    485                    heatran     fire, steel
# 12    494                    victini   psychic, fire
# 13    499                    pignite  fire, fighting
# 14    500                     emboar  fire, fighting
# 15    514                   simisear            fire
# 16    555        darmanitan-standard            fire
# ...

# %%
# mostra il pokemon con più alto attacco
highest_attack_query = text("""
    SELECT * FROM pokemon_stats
    ORDER BY attack DESC
    LIMIT 1
""")
highest_attack_pokemon = pd.read_sql(highest_attack_query, engine)
highest_attack_pokemon
# Out:
#       id           name              types  abilities   hp  attack  defense  \
# 0  10043  mewtwo-mega-x  psychic, fighting  steadfast  106     190      100
#
#    sp_attack  sp_defense  speed  total_stats
# 0        154         100    130          780

# %%
# mostra le stats del pokemon "moltres"
# accedi al database splittando le stats in colonne separate
stats_query = text("""
    SELECT
        name, types,
        CAST(regexp_replace(stats, '^.*hp=([0-9]+).*$','\\1') AS INTEGER) AS hp,
        CAST(regexp_replace(stats, '^.* attack=([0-9]+).*$','\\1') AS INTEGER) AS attack,
        CAST(regexp_replace(stats, '^.* defense=([0-9]+).*$','\\1') AS INTEGER) AS defense,
        CAST(regexp_replace(stats, '^.*special-attack=([0-9]+).*$','\\1') AS INTEGER) AS sp_attack,
        CAST(regexp_replace(stats, '^.*special-defense=([0-9]+).*$','\\1') AS INTEGER) AS sp_defense,
        CAST(regexp_replace(stats, '^.*speed=([0-9]+).*$','\\1') AS INTEGER) AS speed
    FROM pokemon
    WHERE name = 'moltres'
""")
pokemon_stats_df = pd.read_sql(stats_query, engine)
pokemon_stats_df.head()
# Out:
#       name         types  hp  attack  defense  sp_attack  sp_defense  speed
# 0  moltres  fire, flying  90     100       90        125          85     90

# %%
# crea una funzione che accetta un nome di Pokémon e restituisce le sue stats
def get_pokemon_stats(pokemon_name):
    query = text(f"""
        SELECT
            name, types,
            CAST(regexp_replace(stats, '^.*hp=([0-9]+).*$','\\1') AS INTEGER) AS hp,
            CAST(regexp_replace(stats, '^.* attack=([0-9]+).*$','\\1') AS INTEGER) AS attack,
            CAST(regexp_replace(stats, '^.* defense=([0-9]+).*$','\\1') AS INTEGER) AS defense,
            CAST(regexp_replace(stats, '^.*special-attack=([0-9]+).*$','\\1') AS INTEGER) AS sp_attack,
            CAST(regexp_replace(stats, '^.*special-defense=([0-9]+).*$','\\1') AS INTEGER) AS sp_defense,
            CAST(regexp_replace(stats, '^.*speed=([0-9]+).*$','\\1') AS INTEGER) AS speed
        FROM pokemon
        WHERE name = :pokemon_name
    """)
    return pd.read_sql(query, engine, params={"pokemon_name": pokemon_name})

# Esempio di utilizzo della funzione
get_pokemon_stats('rayquaza')
# Out:
#        name           types   hp  attack  defense  sp_attack  sp_defense  \
# 0  rayquaza  dragon, flying  105     150       90        150          90
#
#    speed
# 0     95

# %%
# crea una top 50 dei Pokémon con le migliori stats totali
top_50_query = text("""
    SELECT
        name, types,
        CAST(regexp_replace(stats, '^.*hp=([0-9]+).*$','\\1') AS INTEGER) AS hp,
        CAST(regexp_replace(stats, '^.* attack=([0-9]+).*$','\\1') AS INTEGER) AS attack,
        CAST(regexp_replace(stats, '^.* defense=([0-9]+).*$','\\1') AS INTEGER) AS defense,
        CAST(regexp_replace(stats, '^.*special-attack=([0-9]+).*$','\\1') AS INTEGER) AS sp_attack,
        CAST(regexp_replace(stats, '^.*special-defense=([0-9]+).*$','\\1') AS INTEGER) AS sp_defense,
        CAST(regexp_replace(stats, '^.*speed=([0-9]+).*$','\\1') AS INTEGER) AS speed,
        CAST(regexp_replace(stats, '^.*hp=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.* attack=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.* defense=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.*special-attack=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.*special-defense=([0-9]+).*$','\\1') AS INTEGER) +
        CAST(regexp_replace(stats, '^.*speed=([0-9]+).*$','\\1') AS INTEGER) AS total_stats
    FROM pokemon
    ORDER BY total_stats DESC
    LIMIT 50
""")
top_50_pokemon = pd.read_sql(top_50_query, engine)
top_50_pokemon
# Out:
#                       name              types   hp  attack  defense  \
# 0      eternatus-eternamax     poison, dragon  255     115      250
# 1            mewtwo-mega-x  psychic, fighting  106     190      100
# 2            rayquaza-mega     dragon, flying  105     180      100
# 3            mewtwo-mega-y            psychic  106     150       70
# 4            kyogre-primal              water  100     150       90
# 5           groudon-primal       ground, fire  100     180      160
# 6           necrozma-ultra    psychic, dragon   97     167       97
# 7            arceus-normal             normal  120     120      120
# 8         zygarde-complete     dragon, ground  216     100      121
# 9              latios-mega    dragon, psychic   80     130      100
# 10           garchomp-mega     dragon, ground  108     170      115
# 11             latias-mega    dragon, psychic   80     100      120
# 12          zacian-crowned       fairy, steel   92     150      115
# ...
